# %% [markdown]
#  Teoría de Circuitos II- Belén Torres
#
# # Desafío semanal II

# %% [markdown]
# ![circuito.PNG](attachment:circuito.PNG)

# %% [markdown]
# \begin{equation}
#     Va=\frac{-R2 \cdot \frac{1}{SC}}{R_1(R_2+\frac{1}{SC})} \cdot V_i - \frac{R_2}{(SCR_2+1) \cdot R_3} \cdot Vo
# \end{equation}
#
# \begin{equation}
#     Va=-\frac{R_2}{R_1} \cdot \frac{1}{(SCR_2+1)} \cdot Vi - \frac {R_2}{R_3} \cdot \frac{1}{(SCR_2+1)} \cdot Vo
# \end{equation}
#
# \begin{equation}
#     \frac{Va}{R_3}=Vo \cdot SC
# \end{equation}
#
# \begin{equation}
#     VoSCR_3=- \frac{_R2}{R_1} \cdot \frac{1}{SCR_2+1} \cdot Vi - \frac{R_3}{R_2} \cdot \frac{1}{SCR_2+1} \cdot Vo
# \end{equation}
#
# \begin{equation}
#     Vo(\frac{SCR_3^2 \cdot (SCR_2+1)+R_2}{R_3{{(SCR_2+1)}}})=-\frac{R_2}{R1} \cdot \frac{1}{{(SCR_2+1)}} \cdot Vi
# \end{equation}
#
# \begin{equation}
#     \frac{Vo}{Vi}=-\frac{R_2 R_3}{R_1} \cdot \frac{1}{SCR_3^2(SCR_2+1+R_2}
# \end{equation}
#
#
# \begin{equation}
#     \frac{Vo}{Vi}=-\frac{R_2 R_3}{R_1} \cdot \frac{1}{SCR_3^2(SCR_2+1+R_2)}
# \end{equation}
#
# \begin{equation}
#     \frac{Vo}{Vi}=-\frac{R_2 R_3}{R_1} \cdot \frac{1}{SCR_3^2R_2+SCR_3^2+R2}
# \end{equation}
#
#
#
# \begin{equation}
#     \omega_n= \frac{1}{CR_3}
# \end{equation}
#
# \begin{equation}
#     \frac{\omega_n}{Q}=\frac{1}{C R_2}
# \end{equation}
#
# \begin{equation}
#     Q=CR_2 \omega_n
# \end{equation}
#
# \begin{equation}
#     Q=\frac{1}{CR_3} \cdot R_2C
# \end{equation}
#
# \begin{equation}
#     Q=\frac{R_2}{R_3}
# \end{equation}

# %% [markdown]
# ## Normalizacion de la transferencia
# \begin{equation}
#     Sn=S \cdot \frac{1}{CR_3}
# \end{equation}
# \begin{equation}
#     K=-\frac{R_3}{R_1}
# \end{equation}
#
# \begin{equation}
#     T(S)= K  \frac{{\frac{1}{C^2R_3^2}}} {{\frac{1}{C^2R_3^2}} \cdot (S^2+S \frac{R_3}{R_3}+1)}
# \end{equation}
#
# \begin{equation}
#     T(S)= K  \frac{1}{S^2+S \frac{1}{Q}+1)}
# \end{equation}

# %% [markdown]
# ## Hallo los valores de los componentes

# %% [markdown]
# :
#
# \begin{equation}
#     \omega_n=1 \frac{rad}{seg}
# \end{equation}
#
# \begin{equation}
#     \omega_n=\frac{1}{CR_3}
# \end{equation}
#
# Proponemos C=1F entonces $R_3= 1 \Omega $
#
# Si Q=10
# y $ Q=\frac{R_2}{R_3} $ y como $R_3=1 \Omega$  $R_2=10 \Omega$
#
# $K=-\frac{R_3}{R_1} $
#
# $ \left |K \right | = \left |T(0) \right | = 20 log (\frac{1}{R1}) $
#
# $ T(0)=20dB=-20 log(\frac{1}{R_1}) $
#
# $ 10^{-1} = \frac{1}{R_1} $
# $ R1=10 \Omega $
#
# Simulacion:

# %% [markdown]
# ![Simu1.png](attachment:Simu1.png)

# %% [markdown]
# ![Simu1G.png](attachment:Simu1G.png)

# %% [markdown]
# ### Para que sea Butterworth:
#
# Sabemos que el polinomio de Butter de 2do orden es:
#
# $ S^2+\sqrt{2}S+1 $
#
# Por simple inspección vemos que:
#
# $\omega_n=1\frac{rad}{seg} $  por lo tanto: mantenemos los valores de C y  $ R_3 $
#
# El Q depende directamente de $ R_2 $ y $ R_3 $ pero al ser $R_3=1 \Omega $
#
# $R_2=\frac{1}{\sqrt{2}} = 0,707 \Omega$
#
# Simulando:

# %% [markdown]
# ![Butter.png](attachment:Butter.png)

# %% [markdown]
# ![ButterG.png](attachment:ButterG.png)

# %% [markdown]
# ## Estudio de Sensibilidad

# %% [markdown]
# \begin{equation}
#     \omega_n= \frac{1}{CR_3}
# \end{equation}
# \begin{equation}
#     S_{C}^{\omega_n} =\frac{C}{\omega_n} \cdot \frac{\partial{\omega_n}}{\partial{C}}=\frac{{C}}{\omega_n} \cdot -\frac{1}{R_3 {C^2}}
# \end{equation}
# \begin{equation}
#     S_{C}^{\omega_n} = -\frac{1}{{\omega_n}} \cdot{\omega_n} = -1
# \end{equation}
#
# \begin{equation}
#     S_{Q}^{R_2}
# \end{equation}
#
# \begin{equation}
#     Q=\frac{R_2}{R_3}
# \end{equation}
#
# \begin{equation}
#    S_{Q}^{R_2} =\frac{R_2}{Q} \cdot \frac{\partial{Q}}{\partial{R_2}}
# \end{equation}
#
# \begin{equation}
#    S_{Q}^{R_2} = \frac{R_2}{Q} \cdot \frac{1}{R_3} = \frac{{R_2}}{{R_3}} \cdot \frac{{R_3}}{{R_2}}=1
# \end{equation}
#
# \begin{equation}
#    S_{Q}^{R_3} =\frac{R_3}{Q} \cdot \frac{\partial{Q}}{\partial{R_3}}
# \end{equation}
#
# \begin{equation}
#    S_{Q}^{R_3} = \frac{{R_3}}{Q} \cdot -\frac{R_2}{R_3^{{2}}} = -\frac{{R_3}}{{R_2}} \cdot \frac{{R_2}}{{R_3}}=-1
# \end{equation}
