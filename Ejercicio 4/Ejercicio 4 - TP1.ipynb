# %% [markdown]
# ### Teoría de Circuitos II
# #### Guía Nº1 - Amplificadores OPAMP y OTA
# #### Grupo 1
# # Ejercicio 4

# %% [markdown]
# ![consigna.png](attachment:consigna.png)

# %% [markdown]
# Se propone el siguiente circuito para reemplazar la resistencia que está _**conectada a masa**_

# %% [markdown]
# ![circuito%20OTA1.png](attachment:circuito%20OTA1.png)

# %% [markdown]
# \begin{equation}
# \label{eqn:imp}
# Z_1(s) = \frac{V_1(s)}{I_o(s)}
# \end{equation}
#
# \begin{equation}
# \label{eqn:tra}
# I_o(s) = gm_1 \cdot V_2(s) = \frac{V_1(s) - V_2(s)}{R_1}
# \end{equation}
#
# \begin{equation}
# \label{eqn:final}
# Z_1(s) = R_1 + \frac{1}{gm_1}
# \end{equation}
#
# Emulando nuestro _**resistor serie a masa**_.

# %% [markdown]
# Se propone el siguiente circuito para reemplazar a la resistencia que está _**flotando**_.

# %% [markdown]
# ![circuito%20OTA2.png](attachment:circuito%20OTA2.png)

# %% [markdown]
# \begin{equation}
# \label{eqn:curr}
# I_i(s) = I_o(s) = gm_1 \cdot (V_1(s) - V_o(s)) = gm_2 \cdot V_o(s)
# \end{equation}
#
# De la ecuación anterior tenemos toda la información necesaria para plantear como se comporta el _**divisor resistivo**_
#
# \begin{equation}
# \frac{V_o(s)}{V_1(s)} = \frac{gm_1}{gm_1 + gm_2}
# \end{equation}
#
# \begin{equation}
# Z_1(s) = \frac{gm_1 + gm_2}{gm_1 \cdot gm_2} = R_1 + R_2
# \end{equation}

# %% [markdown]
# # Simulación en LtSpice

# %% [markdown]
# Agregamos el símbolo proporcionado por la cátedra. Y simulamos el divisor de tensión, como cada resistencia tiene un valor de *5k*, el valor de cada \begin{equation}
# gm=200uS
# \end{equation}
# Con este valor entramos por eje de la ordenada con el valor correspondiente hasta interceptar a la recta de **25°** de temperatura,para lo cual nos da un valor de **15uA** cuando interceptamos al eje de la abcisa.

# %% [markdown]
# ![valor%20de%20Iabc.PNG](attachment:valor%20de%20Iabc.PNG)

# %% [markdown]
# ![circuito%20con%20s%C3%ADmbolo.PNG](attachment:circuito%20con%20s%C3%ADmbolo.PNG)

# %% [markdown]
# ![salida-circuito-con%20s%C3%ADmbolo.PNG](attachment:salida-circuito-con%20s%C3%ADmbolo.PNG)

# %% [markdown]
# Con lo podemos observar que la salida una vez reemplazando las resistencias da un divisor resistivo y como el valor de las resistencias es el mismo a la salida tenemos la mitad de la tensión de la entrada.En este caso utilizamos una *fuente de continua* de **200uV** y un valor de *R* de **10**,para representar la corriente de polarización.
